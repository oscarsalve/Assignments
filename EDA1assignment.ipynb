# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.isna()
# Out:
#          LB     AC     FM     UC     DL     DS     DP   ASTV   MSTV   ALTV  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2121  False  False  False  False  False  False  False  False  False  False
# 2122  False  False  False  False  False  False  False  False  False  False
# 2123  False  False  False  False  False  False  False  False  False  False
# 2124  False  False  False  False  False  False  False  False  False  False
# 2125  False  False  False  False  False  False  False  False  False  False
#
#        MLTV  Width  Tendency    NSP
# ...

# %%
print(df.isnull().sum())

# Display unique values in the NSP column (assuming this is the target variable)
print(df['NSP'].value_counts())
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64
# NSP
#  1.000000    1546
#  2.000000     280
#  3.000000     164
# -1.000000       5
#  5.000000       4
#              ...
#  0.992847       1
#  2.971309       1
#  0.984834       1
#  0.991200       1
#  1.990464       1
# Name: count, Length: 111, dtype: int64

# %%
# Handle missing values
# For simplicity, let's fill missing values with the median of each column
for column in df.columns:
    if df[column].isnull().sum() > 0:
        df[column].fillna(df[column].median(), inplace=True)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.violinplot(data=df)
# Out:
# <Axes: >

# %%
# Compute the correlation matrix
corr_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Numerical Variables', fontsize=16)
plt.show()

# %%
df.hist(figsize=(16, 12), bins=20, edgecolor='black')
plt.show()

# %%
sns.pairplot(df, hue='NSP')
plt.show()

# %%
#Summary of Key Insights and Patterns

'''Distribution of Numerical Variables:
The histograms revealed that many of the numerical variables are not normally distributed.
 Some variables are skewed, and others show multimodal distributions.

Outliers Detection:
The boxplots identified several outliers across multiple variables.
 These outliers could represent abnormal or rare fetal conditions that are crucial for understanding pathological cases.

Class Distribution (NSP):
The bar and pie charts of the NSP variable indicated an imbalance in the class distribution, with the majority of cases being classified as Normal.

Correlation Analysis:
The correlation heatmap highlighted strong correlations between certain variables.
 For instance, variables related to short-term and long-term variability (ASTV, MSTV, ALTV, MLTV) showed significant correlations with each other.
  This suggests that these features capture related aspects of fetal heart rate variability and could be critical in classifying the fetal state.

Scatter Plot Insights:
Scatter plots showed that some variables have a distinct separation between NSP categories, indicating that these variables could be strong predictors of fetal health status.
 For example, there may be a noticeable difference in the relationship between ASTV and MLTV when comparing normal and pathological cases.'''

 # A profiling report is also attached to give summary and overview and many more relations etc.
